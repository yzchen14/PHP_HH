# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = sns.load_dataset("penguins") # 讀取數據

# %%
df.query('island == "Dream"')
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 30      Adelie  Dream            39.5           16.7              178.0
# 31      Adelie  Dream            37.2           18.1              178.0
# 32      Adelie  Dream            39.5           17.8              188.0
# 33      Adelie  Dream            40.9           18.9              184.0
# 34      Adelie  Dream            36.4           17.0              195.0
# ..         ...    ...             ...            ...                ...
# 215  Chinstrap  Dream            55.8           19.8              207.0
# 216  Chinstrap  Dream            43.5           18.1              202.0
# 217  Chinstrap  Dream            49.6           18.2              193.0
# 218  Chinstrap  Dream            50.8           19.0              210.0
# 219  Chinstrap  Dream            50.2           18.7              198.0
#
#      body_mass_g     sex
# 30        3250.0  Female
# 31        3900.0    Male
# ...

# %%
df.query('species == "Adelie"')
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 147  Adelie      Dream            36.6           18.4              184.0
# 148  Adelie      Dream            36.0           17.8              195.0
# 149  Adelie      Dream            37.8           18.1              193.0
# 150  Adelie      Dream            36.0           17.1              187.0
# 151  Adelie      Dream            41.5           18.5              201.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
A = pd.DataFrame({"A": [1,2,3,4], "B": [4,5,6,7]})
A
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6
# 3  4  7

# %%
for i, j in zip(range(5), range(5)):
    A = A.append({"A": i, "B":j}, ignore_index=True)

# %%
A['A'].iloc[1] = 4

# %%
A
# Out:
#    A  B
# 0  1  4
# 1  4  5
# 2  3  6
# 3  4  7
# 4  0  0
# 5  1  1
# 6  2  2
# 7  3  3
# 8  4  4
